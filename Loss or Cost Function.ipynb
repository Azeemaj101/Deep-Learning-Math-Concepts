# %%
import numpy as np

# %% [markdown]
# <b>Implement Mean Absolute Error</b> <br> ![image.png](attachment:image.png)

# %%
y_predicted = np.array([1,1,0,0,1])
y_true = np.array([0.30,0.7,1,0,0.5])

# %%
def men(y_predicted, y_true):
    total_error = 0;
    for yp, yt in zip(y_pridicted, y_true):
        total_error += abs(yp- yt) #appox - Real
    print("Total Error", total_error)
    print("Mean Absolute Error", total_error/len(y_true))

# %%
men(y_predicted, y_true)
# Out:
# Total Error 2.5
# Mean Absolute Error 0.5

# %% [markdown]
# ## Implement same thing using numpy in much easier way

# %%
np.mean(np.abs(y_predicted-y_true))
# Out:
# 0.5

# %% [markdown]
# <b>Implement Mean Absolute Error</b> <br> ![image.png](attachment:image.png)

# %%
def mse(y_predicted, y_true):
    total_error = 0;
    for yp, yt in zip(y_pridicted, y_true):
        total_error += pow(abs(yp- yt),2) #appox - Real
    print("Total Error", total_error)
    print("Mean Absolute Error", total_error/len(y_true))

# %%
mse(y_predicted,y_true)
# Out:
# Total Error 1.83
# Mean Absolute Error 0.366

# %% [markdown]
# ### Implement same thing using numpy in much easier way

# %%
np.mean(np.square(y_predicted-y_true))
# Out:
# 0.366

# %% [markdown]
# ## Implement Log Loss or Binary Cross Entropy

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.log([0])
# Out:
# <ipython-input-54-faee82fd9f21>:1: RuntimeWarning: divide by zero encountered in log
#   np.log([0])
# array([-inf])

# %%
np.log([1e-15]) #0.00000000000000001
# Out:
# array([-34.53877639])

# %%
y_predicted
# Out:
# array([1, 1, 0, 0, 1])

# %%
epsilon= 1e-15

# %%
y_predicted_new = [max(i,epsilon) for i in y_predicted]
y_predicted_new
# Out:
# [1, 1, 1e-15, 1e-15, 1]

# %%
y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
y_predicted_new
# Out:
# [0.999999999999999, 0.999999999999999, 1e-15, 1e-15, 0.999999999999999]

# %%
y_predicted_new = np.array(y_predicted_new)

# %%
np.log(y_predicted_new)
# Out:
# array([-9.99200722e-16, -9.99200722e-16, -3.45387764e+01, -3.45387764e+01,
#        -9.99200722e-16])

# %%
-np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))
# Out:
# 17.2696280766844

# %%
def log_loss(y_true, y_predicted):
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
log_loss(y_true, y_predicted)
# Out:
# 17.2696280766844
